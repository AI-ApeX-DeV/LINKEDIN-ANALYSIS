# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\nares\OneDrive\Documents\PythonPrograms\dataSet\linkedin.csv')
df.head()
# Out:
#    index category                                           linkedin  \
# 0      1       HR  https://in.linkedin.com/in/sameer-wadhawan-b55...
# 1      2       HR  https://in.linkedin.com/in/adarsh-krishna-a4ab0a5
# 2      3       HR           https://in.linkedin.com/in/shrivas-mohit
# 3      4       HR       https://in.linkedin.com/in/hr-hopes-086734b8
# 4      5       HR           https://in.linkedin.com/in/rakeshkumar01
#
#                                      profile_picture  \
# 0  https://media-exp1.licdn.com/dms/image/C5603AQ...
# 1  https://media-exp1.licdn.com/dms/image/C5103AQ...
# 2  ......
# 3  ......
# 4  https://media-exp1.licdn.com/dms/image/C5103AQ...
#
#                                          description  \
# 0  An experienced HR professional,  HR mentor and...
# 1  Head Talent Acquisition, HR Leader and Strateg...
# 2  A Talent Acquisition and HR professional with ...
# 3                                                NaN
# ...

# %%
print(df.isnull().sum())
print(df.shape)
# Out:
# index                0
# category             0
# linkedin             0
# profile_picture     12
# description        581
# Experience          25
# Name                12
# position            12
# location            12
# skills               0
# clean_skills         0
# dtype: int64
# (1251, 11)

# %%
# df.drop('index',axis='columns',inplace=True)
# df.drop('linkedin',axis='columns',inplace=True)
# df.drop('skills',axis='columns',inplace=True)
df.drop('location',axis='columns',inplace=True)
df.drop('profile_picture',axis='columns',inplace=True)
df.head()
# Out:
#    index category                                           linkedin  \
# 0      1       HR  https://in.linkedin.com/in/sameer-wadhawan-b55...
# 1      2       HR  https://in.linkedin.com/in/adarsh-krishna-a4ab0a5
# 2      3       HR           https://in.linkedin.com/in/shrivas-mohit
# 3      4       HR       https://in.linkedin.com/in/hr-hopes-086734b8
# 4      5       HR           https://in.linkedin.com/in/rakeshkumar01
#
#                                          description  \
# 0  An experienced HR professional,  HR mentor and...
# 1  Head Talent Acquisition, HR Leader and Strateg...
# 2  A Talent Acquisition and HR professional with ...
# 3                                                NaN
# 4  Over 18 Years of experience in IT /ITES  / BPO...
#
#                                           Experience             Name  \
# 0  Senior Vice President & Head of HRCompany Name...  Sameer Wadhawan
# 1  Head of Talent Acquisition - India & APAC and ...   Adarsh Krishna
# ...

# %%
df['category'].unique()
# Out:
# array(['HR', 'Designing', 'Managment', 'Information Technology',
#        'Education', 'Advocate', 'Business Development',
#        'Health & Fitness', 'Agricultural', 'BPO', 'Sales', 'Consultant',
#        'Digital Media', 'Building & Construction', 'Automobile',
#        'Banking', 'Engineering', 'Food & Beverages', 'Finance', 'Apparel',
#        'Accountant', 'Architects', 'Public Relations', 'Arts', 'Aviation'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1251 entries, 0 to 1250
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         1251 non-null   int64
#  1   category      1251 non-null   object
#  2   linkedin      1251 non-null   object
#  3   description   670 non-null    object
#  4   Experience    1226 non-null   object
#  5   Name          1239 non-null   object
#  6   position      1239 non-null   object
#  7   skills        1251 non-null   object
#  8   clean_skills  1251 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 88.1+ KB

# %%
df['description'].iloc[1]
# Out:
# 'Head Talent Acquisition, HR Leader and Strategic Partner to Business and leadership team in areas of people, processand structure,  worked with some of the best IT Services and Product Organizations.... see more'

# %%
df['merge'] = df['description']+df['position']
df
# Out:
#       index  category                                           linkedin  \
# 0         1        HR  https://in.linkedin.com/in/sameer-wadhawan-b55...
# 1         2        HR  https://in.linkedin.com/in/adarsh-krishna-a4ab0a5
# 2         3        HR           https://in.linkedin.com/in/shrivas-mohit
# 3         4        HR       https://in.linkedin.com/in/hr-hopes-086734b8
# 4         5        HR           https://in.linkedin.com/in/rakeshkumar01
# ...     ...       ...                                                ...
# 1246   1753  Aviation  https://in.linkedin.com/in/britishairhostess-a...
# 1247   1754  Aviation  https://in.linkedin.com/in/ramaiah-manjunath-a...
# 1248   1755  Aviation  https://in.linkedin.com/in/shubham-pradhan-678...
# 1249   1756  Aviation  https://in.linkedin.com/in/alfiya-shaikh-b5818...
# 1250   1757  Aviation         https://in.linkedin.com/in/abhishekvtiwari
#
#                                             description  \
# ...

# %%
# final_df = pd.DataFrame
# pd.final_df['category'] = df['category']
# pd.final_df['Name'] = df['Name']
# pd.final_df['des_pos_skill'] = df['merge']
# pd.final_df

final_df = df[['category','Name','merge','clean_skills']].copy()
final_df.head()
# Out:
#   category             Name  \
# 0       HR  Sameer Wadhawan
# 1       HR   Adarsh Krishna
# 2       HR    Shrivas Mohit
# 3       HR         HR Hopes
# 4       HR     Rakesh Kumar
#
#                                                merge  \
# 0  An experienced HR professional,  HR mentor and...
# 1  Head Talent Acquisition, HR Leader and Strateg...
# 2  A Talent Acquisition and HR professional with ...
# 3                                                NaN
# 4  Over 18 Years of experience in IT /ITES  / BPO...
#
#                                         clean_skills
# 0  ['Performance Management', 'Human Resources', ...
# 1  ['Talent Acquisition', 'Employee Engagement', ...
# 2  ['Human Resources', 'Recruiting', 'Team Manage...
# 3                                               ['']
# 4  ['Team Management', 'Human Resources', 'Employ...

# %%
for i 
final_df['merge'].iloc[0]
# Out:
# "An experienced HR professional,  HR mentor and Coach , Talent advisory and HR strategist... see moreSenior Vice President and Head of HR- Samsung Electronics India Limited['Performance Management', 'Human Resources', 'Talent Management', 'Talent Acquisition', 'Recruiting', 'Strategy', 'Change Management', 'Deferred Compensation', 'Strategic HR', 'HR Policies', 'Compensation & Benefits', 'Business Strategy', 'Strategic Human Resource Planning', 'Succession Planning', 'Vendor Management', 'Workforce Planning', 'HRIS', 'Personnel Management', 'Employee Relations', 'Management', 'Employee Engagement', 'Leadership', 'Team Management', 'Conflict Management', 'People Skills', 'Performance Appraisal', 'Organizational Structure', 'Certified career coach', 'Certified Hogan assessor and coach']"

# %% [markdown]
# ## removing stop words

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nares\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_stopwords(text):
    new_text =[]
    for word in text.split():
        if word in stopwords.words('english'):
            new_text.append('')
        else:
            new_text.append(word)
    x=new_text[:]
    new_text.clear()
    return " ".join(x)

remove_stopwords(lambda x: for i in range )
# Out:
# "An experienced HR professional, HR mentor  Coach , Talent advisory  HR strategist... see moreSenior Vice President  Head  HR- Samsung Electronics India Limited['Performance Management', 'Human Resources', 'Talent Management', 'Talent Acquisition', 'Recruiting', 'Strategy', 'Change Management', 'Deferred Compensation', 'Strategic HR', 'HR Policies', 'Compensation & Benefits', 'Business Strategy', 'Strategic Human Resource Planning', 'Succession Planning', 'Vendor Management', 'Workforce Planning', 'HRIS', 'Personnel Management', 'Employee Relations', 'Management', 'Employee Engagement', 'Leadership', 'Team Management', 'Conflict Management', 'People Skills', 'Performance Appraisal', 'Organizational Structure', 'Certified career coach', 'Certified Hogan assessor  coach']"
